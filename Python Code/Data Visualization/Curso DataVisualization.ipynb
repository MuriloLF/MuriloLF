# %% [markdown]
# # Aula 01 Importando e traduzindo dados

# %%
import pandas as pd
pd.set_option('display.max_rows', 244) #SETA O MAXIMO DE LINHAS QUE APARECERÁ NO DATASET

# %%
dados = pd.read_csv('datas/tips.csv')

# %%
dados
# Out:
#      total_bill    tip dessert   day    time  size
# 0         16.99   1.01      No   Sun  Dinner     2
# 1         10.34   1.66      No   Sun  Dinner     3
# 2         21.01   3.50      No   Sun  Dinner     3
# 3         23.68   3.31      No   Sun  Dinner     2
# 4         24.59   3.61      No   Sun  Dinner     4
# 5         25.29   4.71      No   Sun  Dinner     4
# 6          8.77   2.00      No   Sun  Dinner     2
# 7         26.88   3.12      No   Sun  Dinner     4
# 8         15.04   1.96      No   Sun  Dinner     2
# 9         14.78   3.23      No   Sun  Dinner     2
# 10        10.27   1.71      No   Sun  Dinner     2
# 11        35.26   5.00      No   Sun  Dinner     4
# 12        15.42   1.57      No   Sun  Dinner     2
# 13        18.43   3.00      No   Sun  Dinner     4
# 14        14.83   3.02      No   Sun  Dinner     2
# 15        21.58   3.92      No   Sun  Dinner     2
# 16        10.33   1.67      No   Sun  Dinner     3
# ...

# %%
renomear = {
    'total_bill' : 'valor_da_conta',
    'tip' : 'gorjeta',
    'dessert' : 'sobremesa',
    'day' : 'dia_da_semana',
    'time' : 'hora_do_dia',
    'size' : 'total_de_pessoas'
}

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01        No           Sun      Dinner
# 1           10.34     1.66        No           Sun      Dinner
# 2           21.01     3.50        No           Sun      Dinner
# 3           23.68     3.31        No           Sun      Dinner
# 4           24.59     3.61        No           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No' : 'Não',
    'Yes' : 'Sim'
}

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não           Sun      Dinner
# 1           10.34     1.66       Não           Sun      Dinner
# 2           21.01     3.50       Não           Sun      Dinner
# 3           23.68     3.31       Não           Sun      Dinner
# 4           24.59     3.61       Não           Sun      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas['dia_da_semana'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
dias = {
    'Sun' : 'Domingo',
    'Sat' : 'Sábado',
    'Thur' : 'Quinta',
    'Fri' : 'Sexta'
}

# %%
gorjetas['dia_da_semana'] = gorjetas['dia_da_semana'].map(dias)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Dinner
# 1           10.34     1.66       Não       Domingo      Dinner
# 2           21.01     3.50       Não       Domingo      Dinner
# 3           23.68     3.31       Não       Domingo      Dinner
# 4           24.59     3.61       Não       Domingo      Dinner
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
hora = {
    'Dinner' : 'Jantar',
    'Lunch' : 'Almoço'
}

# %%
gorjetas['hora_do_dia'] = gorjetas['hora_do_dia'].map(hora)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas
# 0                 2
# 1                 3
# 2                 3
# 3                 2
# 4                 4

# %%
gorjetas.describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas
# count      244.000000  244.000000        244.000000
# mean        19.785943    2.998279          2.569672
# std          8.902412    1.383638          0.951100
# min          3.070000    1.000000          1.000000
# 25%         13.347500    2.000000          2.000000
# 50%         17.795000    2.900000          2.000000
# 75%         24.127500    3.562500          3.000000
# max         50.810000   10.000000          6.000000

# %%
gorjetas.head(244)
# Out:
#      valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0             16.99     1.01       Não       Domingo      Jantar
# 1             10.34     1.66       Não       Domingo      Jantar
# 2             21.01     3.50       Não       Domingo      Jantar
# 3             23.68     3.31       Não       Domingo      Jantar
# 4             24.59     3.61       Não       Domingo      Jantar
# 5             25.29     4.71       Não       Domingo      Jantar
# 6              8.77     2.00       Não       Domingo      Jantar
# 7             26.88     3.12       Não       Domingo      Jantar
# 8             15.04     1.96       Não       Domingo      Jantar
# 9             14.78     3.23       Não       Domingo      Jantar
# 10            10.27     1.71       Não       Domingo      Jantar
# 11            35.26     5.00       Não       Domingo      Jantar
# 12            15.42     1.57       Não       Domingo      Jantar
# ...

# %% [markdown]
# # Aula 02 Comparando distribuições

# %%
# !pip install seaborn==0.9.0
# Out:
# ...
#   Using cached seaborn-0.9.0-py3-none-any.whl (208 kB)
# ...
#   Attempting uninstall: seaborn
#     Found existing installation: seaborn 0.10.0
# WARNING: Error parsing requirements for seaborn: [Errno 2] No such file or directory: 'c:\\users\\user\\anaconda3\\lib\\site-packages\\seaborn-0.10.0.dist-info\\METADATA'
# WARNING: Error parsing requirements for python-language-server: [Errno 2] No such file or directory: 'c:\\users\\user\\anaconda3\\lib\\site-packages\\python_language_server-0.31.7.dist-info\\METADATA'
# WARNING: Error parsing requirements for python-jsonrpc-server: [Errno 2] No such file or directory: 'c:\\users\\user\\anaconda3\\lib\\site-packages\\python_jsonrpc_server-0.3.4.dist-info\\METADATA'
# WARNING: Error parsing requirements for pytest-remotedata: [Errno 2] No such file or directory: 'c:\\users\\user\\anaconda3\\lib\\site-packages\\pytest_remotedata-0.3.2.dist-info\\METADATA'
# ...

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# WARNING: No metadata found in c:\users\user\anaconda3\lib\site-packages
# WARNING: No metadata found in c:\users\user\anaconda3\lib\site-packages
# ERROR: Exception:
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3021, in _dep_map
#     return self.__dep_map
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 3012, in _parsed_pkg_info
#     return self._pkg_info
#   File "C:\Users\User\anaconda3\lib\site-packages\pip\_vendor\pkg_resources\__init__.py", line 2815, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _pkg_info
#
# ...

# %%
# Gráfico de plotagem
valor_gorjeta = sns.scatterplot(x= 'valor_da_conta', y= 'gorjeta', data=gorjetas)

# %% [markdown]
# ### Visualmente, o valor da gorjeta aumenta conforme aumenta o valor da conta

# %%
gorjetas.shape
# Out:
# (244, 6)

# %%
# Qtds de registros
print('A base de dados contém {} registros \n'.format(gorjetas.shape[0]))
print('Registros não nulos')
gorjetas.count()
# Out:
# A base de dados contém 244 registros
#
# Registros não nulos
# valor_da_conta      244
# gorjeta             244
# sobremesa           244
# dia_da_semana       244
# hora_do_dia         244
# total_de_pessoas    244
# dtype: int64

# %%
# Criando campo porcentagem
gorjetas['porcentagem'] = gorjetas['gorjeta'] / gorjetas['valor_da_conta']
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2     0.059447
# 1                 3     0.160542
# 2                 3     0.166587
# 3                 2     0.139780
# 4                 4     0.146808

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
porcentagem_conta = sns.scatterplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# ### Visualmente, o valor da conta não é proporcional ao valor da gorjeta

# %%
# Gráfico de linha
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %%
porcentagem_conta_linha = sns.relplot(x='valor_da_conta', y='porcentagem', kind='line', data=gorjetas)

# %%
#Visaulizar progressão
sns.lmplot(x='valor_da_conta', y='porcentagem', data=gorjetas)

# %% [markdown]
# # Aula 03 Analisando de forma visual de descritiva

# %%
gorjetas.head()
# Out:
#    valor_da_conta  gorjeta sobremesa dia_da_semana hora_do_dia  \
# 0           16.99     1.01       Não       Domingo      Jantar
# 1           10.34     1.66       Não       Domingo      Jantar
# 2           21.01     3.50       Não       Domingo      Jantar
# 3           23.68     3.31       Não       Domingo      Jantar
# 4           24.59     3.61       Não       Domingo      Jantar
#
#    total_de_pessoas  porcentagem
# 0                 2         0.06
# 1                 3         0.16
# 2                 3         0.17
# 3                 2         0.14
# 4                 4         0.15

# %%
gorjetas[gorjetas.sobremesa == 'Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem
# count       93.000000  93.000000         93.000000    93.000000
# mean        20.756344   3.008710          2.408602     0.163226
# std          9.832154   1.401468          0.810751     0.085060
# min          3.070000   1.000000          1.000000     0.040000
# 25%         13.420000   2.000000          2.000000     0.110000
# 50%         17.920000   3.000000          2.000000     0.150000
# 75%         26.860000   3.680000          3.000000     0.200000
# max         50.810000  10.000000          5.000000     0.710000

# %%
gorjetas[gorjetas.sobremesa == 'Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem
# count      151.000000  151.000000        151.000000   151.000000
# mean        19.188278    2.991854          2.668874     0.159536
# std          8.255582    1.377190          1.017984     0.039889
# min          7.250000    1.000000          1.000000     0.060000
# 25%         13.325000    2.000000          2.000000     0.140000
# 50%         17.590000    2.740000          2.000000     0.160000
# 75%         22.755000    3.505000          3.000000     0.185000
# max         48.330000    9.000000          6.000000     0.290000

# %%
sns.catplot(x='sobremesa', y='gorjeta', data=gorjetas)

# %%
#hue para criar categorias no grafico
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='gorjeta', col='sobremesa', hue='sobremesa', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', col='sobremesa', hue='sobremesa', data=gorjetas)

# %% [markdown]
# ### Visualemente, existe uma diferença em valor da gorjeta daqueles que pediram sobremesa e não pediram

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='sobremesa', col='sobremesa', kind='line', data=gorjetas)

# %% [markdown]
# ### Teste de hipótese

# %% [markdown]
# #### H0 = A distribuição da taxa da gorjeta é a mesma nos dois grupos
# #### H1 = A distribuição da taxa da gorjeta é diferente nos dois grupos

# %%
from scipy.stats import ranksums

# %%
sobremesa = gorjetas.query('sobremesa == "Sim"').porcentagem

# %%
sem_sobremesa = gorjetas.query('sobremesa == "Não"').porcentagem

# %%
r = ranksums(sobremesa, sem_sobremesa)

# %%
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# ### Aceita hipótese nula por conta do "pvalue"

# %% [markdown]
# # Aula 04 Comparando e analisando os dias da semana

# %%
sns.catplot(x='dia_da_semana', y='valor_da_conta', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='gorjeta', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.relplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
sns.lmplot(x='valor_da_conta', y='porcentagem', hue='dia_da_semana', col='dia_da_semana', data=gorjetas)

# %%
media_geral_gorjetas = gorjetas.gorjeta.mean()

# %%
print('A média geral das gorjetas é de {}'.format(media_geral_gorjetas))
# Out:
# A média geral das gorjetas é de 2.9982786885245902

# %%
gorjetas.groupby(['dia_da_semana']).mean()
# Out:
#                valor_da_conta   gorjeta  total_de_pessoas  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132          2.842105     0.166974
# Quinta              17.682742  2.771452          2.451613     0.161129
# Sexta               17.151579  2.734737          2.105263     0.169474
# Sábado              20.441379  2.993103          2.517241     0.153678

# %%
type(gorjetas.groupby(['dia_da_semana']).mean())
# Out:
# pandas.core.frame.DataFrame

# %%
gorjetas.groupby(['dia_da_semana']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#                valor_da_conta   gorjeta  porcentagem
# dia_da_semana
# Domingo             21.410000  3.255132     0.166974
# Quinta              17.682742  2.771452     0.161129
# Sexta               17.151579  2.734737     0.169474
# Sábado              20.441379  2.993103     0.153678

# %%
print('Frequência dos dias')
gorjetas.dia_da_semana.value_counts()
# Out:
# Frequência dos dias
# Sábado     87
# Domingo    76
# Quinta     62
# Sexta      19
# Name: dia_da_semana, dtype: int64

# %% [markdown]
# ### Teste de Hipótese

# %% [markdown]
# ### H0 = A distribuição do valor da conta é igual no sábado e no domingo
# ### H1 = A distribuição do valor da conta não é igual no sábado e no domingo

# %%
valor_conta_domingo = gorjetas.query("dia_da_semana == 'Domingo'").valor_da_conta

# %%
valor_conta_sabado = gorjetas.query("dia_da_semana == 'Sábado'").valor_da_conta

# %%
r = ranksums(valor_conta_domingo, valor_conta_sabado)

# %%
print('O valor do p-value é {}'.format(r.pvalue))
# Out:
# O valor do p-value é 0.3576728477868443

# %% [markdown]
# ### A distruibção do valor da conta é igual no sábado e no domingo pelo p-value >0,05

# %% [markdown]
# # Aula 05 Distribuição de frequência

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)

# %%
sns.catplot(x='hora_do_dia', y='valor_da_conta', kind='swarm', data=gorjetas) #Analisar melhor todos os pontos

# %%
sns.violinplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
sns.boxplot(x='hora_do_dia', y='valor_da_conta', data=gorjetas)
# Out:
# <AxesSubplot:xlabel='hora_do_dia', ylabel='valor_da_conta'>

# %%
almoco = gorjetas.query("hora_do_dia == 'Almoço'").valor_da_conta

# %%
sns.distplot(almoco)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
sns.distplot(almoco, kde=False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
jantar = gorjetas.query("hora_do_dia == 'Jantar'").valor_da_conta

# %%
sns.distplot(jantar)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
sns.distplot(jantar, kde=False)
# Out:
# <AxesSubplot:xlabel='valor_da_conta'>

# %%
gorjetas.groupby(['hora_do_dia']).mean()[['valor_da_conta', 'gorjeta', 'porcentagem']]
# Out:
#              valor_da_conta   gorjeta  porcentagem
# hora_do_dia
# Almoço            17.168676  2.728088     0.163971
# Jantar            20.797159  3.102670     0.159773

# %% [markdown]
# ### Teste de hipótese

# %% [markdown]
# ### H0 = A distribuição do valor da conta é igual no jantar e no almoço
# ### H1 = A distribuição do valor da conta não é igual no jantar e no almoço

# %%
ranksums(almoco, jantar)
# Out:
# RanksumsResult(statistic=-3.2438872807262955, pvalue=0.0011791039723641672)

# %% [markdown]
# ### Aceitamos a hipótese alternativa

# %%
porcentagem_almoco = gorjetas.query("hora_do_dia == 'Almoço'").porcentagem

# %%
porcentagem_jantar = gorjetas.query("hora_do_dia == 'Jantar'").porcentagem

# %%
ranksums(porcentagem_almoco, porcentagem_jantar)
# Out:
# RanksumsResult(statistic=1.1258018532735787, pvalue=0.2602493995587126)

# %%
r3 = ranksums(porcentagem_almoco, porcentagem_jantar)
print('O valor do p-value é de {}'.format(r3.pvalue))
# Out:
# O valor do p-value é de 0.2602493995587126

# %% [markdown]
# # Relatóriod de Análise VI

# %% [markdown]
# ## Criando novas variaveis

# %%
import pandas as pd

# %%
dados = pd.read_csv('dados/aluguel_residencial.csv', sep = ';')
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         0.0   0.0
# 2       390.0  20.0
# 3       230.0   0.0
# 4       301.0  17.0

# %%
dados['Valor Bruto'] = dados['Valor'] + dados['Condominio'] + dados['IPTU']
dados.head()

# %%
dados['Valor m2'] = dados['Valor']/dados['Area']
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto   Valor m2
# 0       500.0  60.0       2260.0  42.500000
# 1         0.0   0.0       7000.0  70.000000
# 2       390.0  20.0       1210.0  53.333333
# 3       230.0   0.0       1030.0  16.666667
# 4       301.0  17.0       1618.0  26.000000

# %%
dados['Valor m2'] = dados['Valor m2'].round(2) #Arredondamento
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2
# 0       500.0  60.0       2260.0     42.50
# 1         0.0   0.0       7000.0     70.00
# 2       390.0  20.0       1210.0     53.33
# 3       230.0   0.0       1030.0     16.67
# 4       301.0  17.0       1618.0     26.00

# %%
dados['Valor Bruto m2'] = (dados['Valor Bruto']/dados['Area']).round(2)
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2
# 0       500.0  60.0       2260.0     42.50           56.50
# 1         0.0   0.0       7000.0     70.00           70.00
# 2       390.0  20.0       1210.0     53.33           80.67
# 3       230.0   0.0       1030.0     16.67           21.46
# 4       301.0  17.0       1618.0     26.00           32.36

# %%
casa = ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
#Apply aplica uma função em cada registro do DF

dados['Tipo Agregado'] = dados['Tipo'].apply(lambda x: 'Casa' if x in casa else 'Apartamento')

# %%
dados.head(10)
# Out:
#                  Tipo               Bairro  Quartos  Vagas  Suites  Area  \
# 0           Quitinete           Copacabana        1      0       0    40
# 1                Casa      Jardim Botânico        2      0       1   100
# 2         Apartamento               Centro        1      0       0    15
# 3         Apartamento         Higienópolis        1      0       0    48
# 4         Apartamento             Cachambi        2      0       0    50
# 5  Casa de Condomínio      Barra da Tijuca        5      4       5   750
# 6  Casa de Condomínio                Ramos        2      2       0    65
# 7         Apartamento               Grajaú        2      1       0    70
# 8         Apartamento  Lins de Vasconcelos        3      1       1    90
# 9         Apartamento           Copacabana        1      0       1    40
#
#      Valor  Condominio  IPTU  Valor Bruto  Valor m2  Valor Bruto m2  \
# 0   1700.0       500.0  60.0       2260.0     42.50           56.50
# ...

# %% [markdown]
# ## Excluindo variáveis do DF

# %%
dados_aux = pd.DataFrame(dados[['Tipo Agregado', 'Valor m2', 'Valor Bruto', 'Valor Bruto m2']])
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto  Valor Bruto m2
# 0   Apartamento     42.50       2260.0           56.50
# 1          Casa     70.00       7000.0           70.00
# 2   Apartamento     53.33       1210.0           80.67
# 3   Apartamento     16.67       1030.0           21.46
# 4   Apartamento     26.00       1618.0           32.36

# %%
# primeiro Jeito
del dados_aux['Valor Bruto']
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2  Valor Bruto m2
# 0   Apartamento     42.50           56.50
# 1          Casa     70.00           70.00
# 2   Apartamento     53.33           80.67
# 3   Apartamento     16.67           21.46
# 4   Apartamento     26.00           32.36

# %%
# segundo Jeito
dados_aux.pop('Valor Bruto m2')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\alura_pandas\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Valor Bruto m2'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-7c888b58fe96> in <module>
#       1 # segundo Jeito
# ...

# %%
dados_aux.head()
# Out:
#   Tipo Agregado  Valor m2
# 0   Apartamento     42.50
# 1          Casa     70.00
# 2   Apartamento     53.33
# 3   Apartamento     16.67
# 4   Apartamento     26.00

# %%
dados.drop(['Valor Bruto', 'Valor Bruto m2'], axis = 1, inplace = True) #axis = 1 para excluir colunas

# %%
dados.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 2  Apartamento           Centro        1      0       0    15   800.0
# 3  Apartamento     Higienópolis        1      0       0    48   800.0
# 4  Apartamento         Cachambi        2      0       0    50  1300.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       500.0  60.0     42.50   Apartamento
# 1         0.0   0.0     70.00          Casa
# 2       390.0  20.0     53.33   Apartamento
# 3       230.0   0.0     16.67   Apartamento
# 4       301.0  17.0     26.00   Apartamento

# %%
dados.to_csv('dados/aluguel_residencial.csv', sep = ';', index = False)
